# %%
import xarray as xr
import matplotlib.pyplot as plt
import numpy as np
from matplotlib import animation, rc
from IPython.display import HTML

# %%
ds_layer=xr.open_dataset('layer/results/ocean.stats.intel.nc')
ds_ALErho=xr.open_dataset('ALE/rho/results/ocean.stats.intel.nc')
ds_ALEz=xr.open_dataset('ALE/zstar/results/ocean.stats.intel.nc')

# %%
ds_layer['En'].plot(label='Layer')
ds_ALErho['En'].plot(label='ALE-rho')
ds_ALEz['En'].plot(label='ALE-z*')
lgnd=plt.legend()
plt.grid()
